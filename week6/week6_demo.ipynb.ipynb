# %% [markdown]
# # Matplotlib基本練習

# %% [markdown]
# # 1.繪製簡單的折線圖

# %%
# 請在"填空"處，輸入所需要的指令或參數

import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}

df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
df["價格"].plot(kind="line") # 繪製折線圖
plt.grid(True) # 顯示圖表的格線

# %%
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2024-03-26 06:23:44--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 173.194.210.113, 173.194.210.139, 173.194.210.138, ...
# Connecting to drive.google.com (drive.google.com)|173.194.210.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-03-26 06:23:44--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.213.132, 2607:f8b0:400c:c0a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.213.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# TaipeiSansTCBeta-Re 100%[===================>]  19.70M  --.-KB/s    in 0.1s
#
# 2024-03-26 06:23:45 (169 MB/s) - ‘TaipeiSansTCBeta-Regular.ttf’ saved [20659344/20659344]

# %% [markdown]
# # 2.顯示x軸和y軸的說明標籤

# %%
# 請在"填空"處，輸入所需要的指令或參數
# Line 3-12行請複製上一題3-12行的解答
import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}

df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
df["價格"].plot(kind="line") # 繪製折線圖
plt.grid(True) # 顯示圖表的格線

# 延伸上一題相同內容

plt.plot([0, 1, 2, 3, 4, 5], df["價格"])
plt.xlabel("商店")
plt.ylabel("價格")
# Out:
# Text(0, 0.5, '價格')

# %% [markdown]
# # 3.請繪製水平長條圖

# %%
# 請在"填空"處，輸入所需要的指令或參數
# Line 3-18行請複製上一題3-18行的解答
import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}

df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
plt.subplot(2, 1, 1)
df["價格"].plot(kind="line") # 繪製折線圖
plt.grid(True) # 顯示圖表的格線
# 延伸上一題相同內容


plt.plot([0, 1, 2, 3, 4, 5], df["價格"])
plt.xlabel("商店")
plt.ylabel("價格")
# 延伸上一題相同內容
# 水平長條圖 (X軸是價格金額，Y軸是商店名稱)
plt.subplot(2, 1, 2)
df["價格"].plot(kind="barh")
plt.plot(df["價格"], df["商店"])
plt.xlabel("價格金額")
plt.ylabel("商店名稱")
# Out:
# Text(0, 0.5, '商店名稱')

# %% [markdown]
# # 4.請繪製派圖

# %%
# 請在"填空"處，輸入所需要的指令或參數
# Line 3-22行請複製上一題3-22行的解答
import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}

df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
plt.subplot(3, 2, 1)
df["價格"].plot(kind="line") # 繪製折線圖
plt.grid(True) # 顯示圖表的格線
# 延伸上一題相同內容


plt.plot([0, 1, 2, 3, 4, 5], df["價格"])
plt.xlabel("商店")
plt.ylabel("價格")
# 延伸上一題相同內容
# 水平長條圖 (X軸是價格金額，Y軸是商店名稱)
plt.subplot(3, 2, 2)
df["價格"].plot(kind="barh")
plt.plot(df["價格"], df["商店"])
plt.xlabel("價格金額")
plt.ylabel("商店名稱")

# 延伸上一題相同內容
# 派圖(groupby 是依據"分類"的數據，標題是商店名稱)
plt.subplot(3, 2, 5)
df_grouped = df.groupby("分類")
type = df_grouped["分類"].count()
type.plot(kind="pie", title="商店名稱")
plt.ylabel("分類")
# Out:
# Text(0, 0.5, '分類')
